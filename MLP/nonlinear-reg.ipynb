# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot as plt
import seaborn as sns

# %%
def mymodel(x):
    return np.exp(-17*(x-0.5)**2)

# %%
n = 60
x = np.random.uniform(0, 1, n).reshape((-1,1))
mu = 0
sigma = 0.1
y = mymodel(x) + np.random.normal(mu, sigma, n).reshape((-1,1))
plt.plot(x,y,'.')
plt.show()

# %%
from sklearn.neural_network import MLPRegressor

mlp = MLPRegressor(hidden_layer_sizes = (20,20), activation = 'logistic', solver = 'lbfgs', max_iter=500).fit(x,np.ravel(y))
#mlp = MLPRegressor(solver = 'lbfgs', activation = 'tanh').fit(x,np.ravel(y))
#mlp = MLPRegressor(solver = 'lbfgs', activation = 'relu').fit(x,np.ravel(y))
#mlp = MLPRegressor(solver = 'lbfgs', activation = 'logistic', max_iter=1000, hidden_layer_sizes=(20,20)).fit(x,np.ravel(y))

# %%
xp = np.linspace(0, 1, num=40).reshape((-1,1))
ypred = mlp.predict(xp)
ytrue = mymodel(xp)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.plot(x,y,'.')
ax1.plot(xp,ypred)
ax2.plot(xp,ytrue)
ax2.plot(xp,ypred)
plt.show()

# %%
mlp.n_layers_
# Out:
# 4
